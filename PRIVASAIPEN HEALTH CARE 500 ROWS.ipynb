# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as  plt
# %matplotlib inline
import seaborn as sns
# Out:
# C:\Users\leowa\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# C:\Users\leowa\anaconda3\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.4' currently installed).
#   from pandas.core import (

# %%
df=pd.read_csv("C:/Users/leowa/Downloads/medical_insurance_nullvalues.csv")

# %%
df
# Out:
#       membership_period  label  patient_suffix  number_of_dependants  \
# 0                1541.0    0.0           789.0                   4.0
# 1                8269.0    0.0           860.0                   3.0
# 2                6223.0    0.0           374.0                   2.0
# 3                8832.0    0.0           729.0                   3.0
# 4                8804.0    1.0           716.0                   2.0
# ...                 ...    ...             ...                   ...
# 6995                NaN    0.0           595.0                   3.0
# 6996              438.0    NaN           158.0                   1.0
# 6997             8134.0    0.0           743.0                   1.0
# 6998             8293.0    1.0           472.0                   3.0
# 6999             3686.0    0.0           625.0                   4.0
#
#       patient_dob   location   Age  Fee Charged patient_name         name  \
# ...

# %%
df.shape
# Out:
# (7000, 14)

# %%
df.columns
# Out:
# Index(['membership_period', 'label', 'patient_suffix', 'number_of_dependants',
#        'patient_dob', 'location', 'Age', 'Fee Charged', 'patient_name', 'name',
#        'gender', 'cause', 'number_of_claims', 'employer'],
#       dtype='object')

# %% [markdown]
# # extract best 500 rows

# %%
# Drop rows with any null values
df1 = df.dropna()

# Optionally sort by a specific column, replace 'column_name' with your desired column
df_sorted = df1.sort_values(by='label', ascending=False)

# Get the top 500 rows
top_500_rows = df_sorted.head(500)

# If you want to save the result to a new CSV
top_500_rows.to_csv('top_500_rows.csv', index=False)

# Display the resulting DataFrame
print(top_500_rows)
# Out:
#       membership_period  label  patient_suffix  number_of_dependants  \
# 3881             7784.0    1.0           792.0                   4.0
# 2948             5626.0    1.0           849.0                   2.0
# 1390             8066.0    1.0           799.0                   3.0
# 4676             7394.0    1.0           755.0                   3.0
# 1384             1714.0    1.0           262.0                   4.0
# ...                 ...    ...             ...                   ...
# 4753             2868.0    0.0           398.0                   4.0
# 4757             1662.0    0.0           919.0                   4.0
# 4758              144.0    0.0           468.0                   2.0
# 4777             1063.0    0.0           104.0                   1.0
# 4779             3051.0    0.0           805.0                   2.0
#
#       patient_dob   location   Age  Fee Charged patient_name         name  \
# ...

# %%
best = pd.read_csv("C:/Users/leowa/Downloads/top_500_rows.csv")

# %%
best
# Out:
#      membership_period  label  patient_suffix  number_of_dependants  \
# 0               8832.0    0.0           729.0                   3.0
# 1               3984.0    0.0           288.0                   3.0
# 2               4771.0    0.0           581.0                   2.0
# 3               6083.0    0.0           367.0                   1.0
# 4               5798.0    0.0           766.0                   4.0
# ..                 ...    ...             ...                   ...
# 495             5091.0    0.0           937.0                   4.0
# 496             6861.0    0.0           340.0                   2.0
# 497             8653.0    0.0           161.0                   4.0
# 498             2924.0    0.0           536.0                   2.0
# 499             2737.0    0.0           797.0                   4.0
#
#      patient_dob   location   Age  Fee Charged patient_name      name  gender  \
# ...

# %%
best.isnull()
# Out:
#      membership_period  label  patient_suffix  number_of_dependants  \
# 0                False  False           False                 False
# 1                False  False           False                 False
# 2                False  False           False                 False
# 3                False  False           False                 False
# 4                False  False           False                 False
# ..                 ...    ...             ...                   ...
# 495              False  False           False                 False
# 496              False  False           False                 False
# 497              False  False           False                 False
# 498              False  False           False                 False
# 499              False  False           False                 False
#
#      patient_dob  location    Age  Fee Charged  patient_name   name  gender  \
# ...

# %%
import pandas as pd
from IPython.display import FileLink, display

# Your data processing code
df1 = df.dropna()
df_sorted = df1.sort_values(by='gender', ascending=True)
top_500_rows = df_sorted.head(500)

# Save to CSV
file_path = "top_500_rows.csv"
top_500_rows.to_csv(file_path, index=False)

# Create a download link
display(FileLink(file_path))
# Out:
# C:\Users\leowa\top_500_rows.csv
